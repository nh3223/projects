# %%
import folium

# %%
m=folium.Map(location=[47.681568,-122.341133])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('green_lake.html')

# %%
folium.Map(location=[50.1163,-122.9574],tiles='Stamen Terrain', zoom_start=15)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
green_lake=folium.Map(location=[47.681568,-122.341133],zoom_start = 14)

home = folium.Marker(
    location=[47.688904,-122.34635],
    popup='Home',
    icon=folium.Icon(icon='home',color='green'))

home.add_to(green_lake)

green_lake
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import numpy as np

data = (np.random.normal(size=(100,3)) * np.array([[1,1,1]]) + np.array([48,5,1])).tolist()
data
# Out:
# [[48.627333738134844, 4.111010535633854, 1.7839251224413122],
#  [47.502583871224104, 5.48138828035858, 1.4913757383152504],
#  [47.61095916492138, 4.89158644923965, 2.090061140922254],
#  [48.914779438156664, 3.407093331731067, 1.027500783693277],
#  [49.987528208917674, 5.562538364835295, -0.6766526703568208],
#  [47.49237913403421, 3.847947258482243, 1.255334692889063],
#  [47.758798447370964, 6.384649175572904, 2.2808803770023367],
#  [49.00895071234683, 3.982257557494853, -0.08843534490447724],
#  [48.67759140756486, 3.681788380810235, 1.643299437863509],
#  [46.92325451677092, 4.219758045194653, -0.7592497320715343],
#  [47.60050534368879, 6.092243742819143, 0.8077951265276491],
#  [50.163200044721094, 4.897344168994592, 1.2917253532667408],
#  [46.46072039565636, 3.7950181734410036, 2.6638015123027268],
#  [46.594893122875, 4.925944096174554, 0.7268047233172423],
#  [46.17377348726391, 4.924475650158991, 3.2888099745779216],
# ...

# %%
from folium.plugins import HeatMap
m = folium.Map([48., 5.], tiles='stamentoner', zoom_start=6)

HeatMap(data).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
