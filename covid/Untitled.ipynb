# %% [markdown]
# # Covid US Time Series

# %%
import numpy as np
import pandas as pd

# %%
file_path = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'

# %%
US_time_series_data = pd.read_csv(file_path, error_bad_lines=False)

# %%
US_time_series_data = US_time_series_data.reset_index().set_index('Province_State')

# %%
US_time_series_data
# Out:
#                           index       UID iso2 iso3  code3     FIPS  \
# Province_State
# American Samoa                0        16   AS  ASM     16     60.0
# Guam                          1       316   GU  GUM    316     66.0
# Northern Mariana Islands      2       580   MP  MNP    580     69.0
# Puerto Rico                   3       630   PR  PRI    630     72.0
# Virgin Islands                4       850   VI  VIR    850     78.0
# ...                         ...       ...  ...  ...    ...      ...
# Washington                 3248  84090053   US  USA    840  90053.0
# West Virginia              3249  84090054   US  USA    840  90054.0
# Wisconsin                  3250  84090055   US  USA    840  90055.0
# Wyoming                    3251  84090056   US  USA    840  90056.0
# Grand Princess             3252  84099999   US  USA    840  99999.0
#
#                               Admin2 Country_Region      Lat     Long_  ...  \
# ...

# %%
WA_time_series_data = US_time_series_data[US_time_series_data.index == 'Washington']

# %%
WA_time_series_data
# Out:
#                 index       UID iso2 iso3  code3     FIPS        Admin2  \
# Province_State
# Washington       2958  84053001   US  USA    840  53001.0         Adams
# Washington       2959  84053003   US  USA    840  53003.0        Asotin
# Washington       2960  84053005   US  USA    840  53005.0        Benton
# Washington       2961  84053007   US  USA    840  53007.0        Chelan
# Washington       2962  84053009   US  USA    840  53009.0       Clallam
# Washington       2963  84053011   US  USA    840  53011.0         Clark
# Washington       2964  84053013   US  USA    840  53013.0      Columbia
# Washington       2965  84053015   US  USA    840  53015.0       Cowlitz
# Washington       2966  84053017   US  USA    840  53017.0       Douglas
# Washington       2967  84053019   US  USA    840  53019.0         Ferry
# Washington       2968  84053021   US  USA    840  53021.0      Franklin
# Washington       2969  84053023   US  USA    840  53023.0      Garfield
# ...
